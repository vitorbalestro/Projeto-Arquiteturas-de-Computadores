# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

tweet_data = pd.read_csv('open_twitter_human_bots_dataset.csv',index_col=0)
X = tweet_data.drop(columns=['split','profile_background_image_path','profile_image_path','account_type','profile_background_image_url','profile_image_url','id','screen_name','description','lang','location','created_at'])

enc = LabelEncoder()

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_train
# Out:
#        default_profile  default_profile_image  favourites_count  \
# 9920             False                  False             12496
# 17113             True                  False               739
# 36643             True                  False              1186
# 32954             True                  False              1658
# 4358             False                  False             11395
# ...                ...                    ...               ...
# 11263             True                  False              2809
# 28977            False                  False                30
# 16013            False                  False               826
# 21624            False                  False              2264
# 3704              True                  False             12013
#
#        followers_count  friends_count  geo_enabled  statuses_count  verified  \
# 9920            393947         389468         True            7037     False
# ...

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array(['bot', 'human', 'human', ..., 'bot', 'human', 'human'],
#       dtype=object)

# %%
score = accuracy_score(y_test,predictions)
score * 100
# Out:
# 82.61217948717949
